# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARMA, ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from arch import arch_model
import matplotlib.pyplot as plt
import sys
import scipy as sp
import matplotlib.pyplot as plt
# import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest
# %matplotlib inline

# %%
sales_df=pd.read_csv("sales_promo_data_19_20.csv", parse_dates=True)

# %%
sales_df.tail()
# Out:
#            Category  5-Jan-19  12-Jan-19  19-Jan-19  26-Jan-19  2-Feb-19  \
# 15    shaving_promo         0          0          0          0         0
# 16        Sunscreen   1661749    1434750    1423463    1366366   1496036
# 17  sunscreen_promo         0          0          0          0         0
# 18           Tanner     84682      78632      81813      82477     89832
# 19     tanner_promo         0          0          0          0         0
#
#     9-Feb-19  16-Feb-19  23-Feb-19  2-Mar-19  ...  27-Jun-20  4-Jul-20  \
# 15         0          0          0         0  ...          0         0
# 16   1838132    2138131    2443552   2793423  ...   10271589  11106721
# 17         0          0          0         0  ...          1         1
# 18    104680     109791     111713    125240  ...     217349    226920
# 19         0          0          0         0  ...          0         0
#
#     11-Jul-20  18-Jul-20  25-Jul-20  1-Aug-20  8-Aug-20  15-Aug-20  22-Aug-20  \
# 15          0          0          0         0         0          0          0
# 16    9383774    8412377    7211073   6410886   5008472    5074913    4078391
# 17          1          0          0         0         1          1          1
# 18     187838     175613     160136    152533    133586     130342     119494
# 19          0          0          0         0         0          0          0
#
#     29-Aug-20
# 15          0
# 16    3295517
# 17          1
# 18     111080
# 19          0
#
# [5 rows x 88 columns]

# %%
sales_df=sales_df.rename(columns={"Category":"Date"})

# %%
sales_df.index = pd.to_datetime(sales_df.index)

# %%
sales_df=sales_df.T

# %%
sales_df.columns= sales_df.iloc[0]

# %%
sales_df=sales_df.iloc[1:,:]
sales_df.head()
# Out:
# Date           Acne acne_promo     Baby baby_promo   Bath bath_promo  \
# 5-Jan-19   14969813          0  1417338          0  55558          0
# 12-Jan-19  15488855          0  1515492          0  59528          0
# 19-Jan-19  15522357          0  1562793          0  56189          0
# 26-Jan-19  15054219          0  1555259          0  56073          0
# 2-Feb-19   14585357          0  1638797          0  60760          0
#
# Date      Body Wash body_promo     Hair hair_promo   Lotion lotion_promo  \
# 5-Jan-19    1491216          0   929666          0  3227827            0
# 12-Jan-19   1599429          0  1042393          0  3551875            0
# 19-Jan-19   1409114          0  1048880          0  3435812            0
# 26-Jan-19   1387046          0  1104388          0  3406859            0
# 2-Feb-19    1479577          0  1235337          0  3754491            0
#
# Date        Makeup makeup_promo Shaving shaving_promo Sunscreen  \
# 5-Jan-19   7156661            0  273010             0   1661749
# 12-Jan-19  7188663            0  283501             0   1434750
# 19-Jan-19  7173238            0  266646             0   1423463
# 26-Jan-19  6851425            0  264479             0   1366366
# 2-Feb-19   6745738            0  265783             0   1496036
#
# Date      sunscreen_promo Tanner tanner_promo
# 5-Jan-19                0  84682            0
# 12-Jan-19               0  78632            0
# 19-Jan-19               0  81813            0
# 26-Jan-19               0  82477            0
# 2-Feb-19                0  89832            0

# %%
sales_df.index = pd.to_datetime(sales_df.index)

# %%
acne_df= sales_df[["Acne","acne_promo"]]
baby_df= sales_df[["Baby","baby_promo"]]
bath_df= sales_df[["Bath","bath_promo"]]
body_df= sales_df[["Body Wash","body_promo"]]
hair_df= sales_df[["Hair","hair_promo"]]
lotion_df= sales_df[["Lotion","lotion_promo"]]
makeup_df= sales_df[["Makeup","makeup_promo"]]
shaving_df= sales_df[["Shaving","shaving_promo"]]
sunscreen_df= sales_df[["Sunscreen","sunscreen_promo"]]
tanner_df= sales_df[["Tanner","tanner_promo"]]

# %%
acne_df.dtypes
# Out:
# Date
# Acne          object
# acne_promo    object
# dtype: object

# %%
acne_df=acne_df.astype(int)
acne_df=acne_df.dropna()

# %%
makuep_df=makeup_df.astype(int)
makeup_df=makeup_df.dropna()

# %%
lotion_df=lotion_df.astype(int)
lotion_df=lotion_df.dropna()

# %%
ax= acne_df["Acne"].plot()

# %%
df1 = acne_df["Acne"]
df2 = makuep_df["Makeup"]
df3 = lotion_df["Lotion"]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df3.plot()
# Out:
# <AxesSubplot:>

# %%
#Decomposing Acne Data
decomp = sm.tsa.seasonal_decompose(acne_df['Acne'],freq=40) 
acne_decomp_data = pd.concat([acne_df, decomp.trend, decomp.seasonal, decomp.resid], axis=1)
acne_decomp_data.columns = ['Acne','acne_promo', 'trend', 'seasonal', 'resid']

acne_decomp_data.head()
# Out:
# <ipython-input-290-3b7d6bb62a07>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomp = sm.tsa.seasonal_decompose(acne_df['Acne'],freq=40)
#                 Acne  acne_promo  trend      seasonal  resid
# 2019-01-05  14969813           0    NaN -1.104916e+06    NaN
# 2019-01-12  15488855           0    NaN -8.138378e+05    NaN
# 2019-01-19  15522357           0    NaN -1.297061e+06    NaN
# 2019-01-26  15054219           0    NaN -1.299645e+06    NaN
# 2019-02-02  14585357           0    NaN  7.656801e+04    NaN

# %%
#Seasonality of Acne
acne_decomp_data['seasonal'].plot()
# Out:
# <AxesSubplot:>

# %%
#Trend of Acne Sales
acne_decomp_data['trend'].dropna()
acne_decomp_data['trend'].plot()
# Out:
# <AxesSubplot:>

# %%
acne_decomp_data['resid'].plot()
# Out:
# <AxesSubplot:>

# %%
#ADFuller Test -Seasonal Data is Stationary Acne
result = adfuller(acne_decomp_data["seasonal"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.4608236256256397
# n_lags: 0.1252995928443032
# p-value: 0.1252995928443032
# Critial Values:
#    1%, -3.5219803175527606
# Critial Values:
#    5%, -2.9014701097664504
# Critial Values:
#    10%, -2.58807215485756

# %%
#Acne Transform to stationary
acne_df['returns']= acne_df['Acne'].pct_change()
acne_df=acne_df.dropna()
acne_df.head()
# Out:
# Date            Acne  acne_promo   returns
# 2019-01-12  15488855           0  0.034673
# 2019-01-19  15522357           0  0.002163
# 2019-01-26  15054219           0 -0.030159
# 2019-02-02  14585357           0 -0.031145
# 2019-02-09  14753443           0  0.011524

# %%
acne_df['returns'].plot()
# Out:
# <AxesSubplot:>

# %%
#Acne Autocorrelation
plot_acf(acne_df['Acne'], lags=40)

# %%
#Acne Partial Autocorrelation
plot_pacf(acne_df['Acne'], zero=False, lags= 40)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#Acne GARCH Model
returns = acne_df['Acne'].pct_change() * 100
returns = returns.dropna()
returns.tail()
# Out:
# 2020-08-01    0.059701
# 2020-08-08    3.420426
# 2020-08-15   -0.419845
# 2020-08-22   -1.604021
# 2020-08-29   -4.336733
# Name: Acne, dtype: float64

# %%
model = arch_model(returns, mean='Zero', vol='GARCH')

# %%
res = model.fit(disp='off')

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   Acne   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.012
# Vol Model:                      GARCH   Log-Likelihood:               -246.010
# Distribution:                  Normal   AIC:                           498.019
# Method:            Maximum Likelihood   BIC:                           505.347
#                                         No. Observations:                   85
# Date:                Sat, Aug 07 2021   Df Residuals:                       85
# Time:                        10:34:32   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          3.1071      1.336      2.326  2.001e-02    [  0.489,  5.725]
# alpha[1]       0.3055      0.169      1.804  7.129e-02 [-2.648e-02,  0.638]
# beta[1]        0.5822      0.118      4.921  8.590e-07    [  0.350,  0.814]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
fig = res.plot(annualize='W')

# %%
#Acne Future forecast 252 days
forecast_horizon = 252
forecasts = res.forecast(start='29-AUG-20', horizon=forecast_horizon)
forecasts
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate.head()
# Out:
#                 h.001      h.002      h.003      h.004      h.005      h.006  \
# 2020-08-29  60.681507  63.652842  66.178783  68.342859  70.208022  71.823136
#
#                 h.007      h.008     h.009      h.010  ...      h.243  \
# 2020-08-29  73.227016  74.451049  75.52099  76.458222  ...  83.496633
#
#                 h.244      h.245      h.246      h.247      h.248      h.249  \
# 2020-08-29  83.496633  83.496633  83.496633  83.496633  83.496633  83.496633
#
#                 h.250      h.251      h.252
# 2020-08-29  83.496633  83.496633  83.496633
#
# [1 rows x 252 columns]

# %%
final = intermediate.dropna().T
final
# Out:
#        2020-08-29
# h.001   60.681507
# h.002   63.652842
# h.003   66.178783
# h.004   68.342859
# h.005   70.208022
# ...           ...
# h.248   83.496633
# h.249   83.496633
# h.250   83.496633
# h.251   83.496633
# h.252   83.496633
#
# [252 rows x 1 columns]

# %%
#ACNE SARIMA Model
model=SARIMAX(endog=acne_df['Acne'], order=(2,1,2),
              seasonal_order=(2,1,2,12),
              trend='c',enforce_invertibility=False
             )
acne_results=model.fit()
print(acne_results.summary())
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               Acne   No. Observations:                   86
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -1107.687
# Date:                            Sat, 07 Aug 2021   AIC                           2235.373
# Time:                                    10:34:45   BIC                           2258.278
# Sample:                                01-12-2019   HQIC                          2244.501
#                                      - 08-29-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1833.3919   9.87e+04      0.019      0.985   -1.92e+05    1.95e+05
# ar.L1          1.1714      0.109     10.731      0.000       0.957       1.385
# ar.L2         -0.9369      0.094    -10.003      0.000      -1.121      -0.753
# ma.L1         -1.0871      0.108    -10.082      0.000      -1.298      -0.876
# ma.L2          0.9316      0.121      7.711      0.000       0.695       1.168
# ar.S.L12      -0.4963      0.373     -1.331      0.183      -1.227       0.234
# ar.S.L24       0.4606      0.266      1.729      0.084      -0.061       0.983
# ma.S.L12       0.2092      0.600      0.348      0.727      -0.968       1.386
# ma.S.L24      -0.7772      0.479     -1.624      0.104      -1.715       0.161
# sigma2      1.165e+12      0.001   1.16e+15      0.000    1.17e+12    1.17e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):                 1.23
# Prob(Q):                              0.43   Prob(JB):                         0.54
# Heteroskedasticity (H):               1.97   Skew:                            -0.11
# Prob(H) (two-sided):                  0.10   Kurtosis:                         3.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.29e+31. Standard errors may be unstable.
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
acne_results.plot_diagnostics(figsize=(20,10))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#Acne Arima Model
acne_arima_mod = ARIMA(acne_df["Acne"], order=(2,1,2))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'

# %%
acne_arima_results = acne_arima_mod.fit()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:701: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:701: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:702: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:702: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '

# %%
acne_arima_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.Acne   No. Observations:                   85
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1258.302
# Method:                       css-mle   S.D. of innovations         631714.940
# Date:                Sat, 07 Aug 2021   AIC                           2528.604
# Time:                        10:34:57   BIC                           2543.260
# Sample:                    01-19-2019   HQIC                          2534.499
#                          - 08-29-2020
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -2.564e+04   8410.771     -3.049      0.002   -4.21e+04   -9155.801
# ar.L1.D.Acne    -0.1883      0.093     -2.035      0.042      -0.370      -0.007
# ar.L2.D.Acne     0.5802      0.093      6.258      0.000       0.398       0.762
# ma.L1.D.Acne          0      0.061          0      1.000      -0.119       0.119
# ma.L2.D.Acne    -1.0000      0.061    -16.468      0.000      -1.119      -0.881
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1606           +0.0000j            1.1606            0.5000
# AR.2            1.4851           +0.0000j            1.4851            0.0000
# MA.1           -1.0000           +0.0000j            1.0000            0.5000
# MA.2            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %%
acne_arima_results.plot_predict()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
#Lotion Product Sales
lotion_df.head()
# Out:
# Date         Lotion  lotion_promo
# 2019-01-05  3227827             0
# 2019-01-12  3551875             0
# 2019-01-19  3435812             0
# 2019-01-26  3406859             0
# 2019-02-02  3754491             0

# %%
#Decomposing Lotion Data
decomp = sm.tsa.seasonal_decompose(lotion_df['Lotion'],freq=40)
lotion_decomp_data = pd.concat([lotion_df, decomp.trend, decomp.seasonal, decomp.resid], axis=1)
lotion_decomp_data.columns = ['Lotion','lotion_promo', 'trend', 'seasonal', 'resid']

lotion_decomp_data.head()
# Out:
# <ipython-input-314-fb32bc25d940>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomp = sm.tsa.seasonal_decompose(lotion_df['Lotion'],freq=40)
#              Lotion  lotion_promo  trend       seasonal  resid
# 2019-01-05  3227827             0    NaN -318665.059219    NaN
# 2019-01-12  3551875             0    NaN  119273.878281    NaN
# 2019-01-19  3435812             0    NaN -196895.846719    NaN
# 2019-01-26  3406859             0    NaN  -42111.259219    NaN
# 2019-02-02  3754491             0    NaN  404872.640781    NaN

# %%
lotion_decomp_data['seasonal'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_decomp_data['trend'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_decomp_data['resid'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_noise, lotion_trend = sm.tsa.filters.hpfilter(lotion_df['Lotion'])

# %%
lotion_noise.plot()
# Out:
# <AxesSubplot:>

# %%
lotion_trend.plot()
# Out:
# <AxesSubplot:>

# %%
#ADFuller Test -Seasonal Data is Stationary
result = adfuller(lotion_decomp_data["seasonal"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -3.8250431208140463
# n_lags: 0.0026612364560095678
# p-value: 0.0026612364560095678
# Critial Values:
#    1%, -3.5087828609430614
# Critial Values:
#    5%, -2.895783561573195
# Critial Values:
#    10%, -2.5850381719848565

# %%
#Acne Transform to stationary
acne_df['returns']= acne_df['Acne'].pct_change()
acne_df=acne_df.dropna()
acne_df.head()
# Out:
# Date            Acne  acne_promo   returns
# 2019-01-19  15522357           0  0.002163
# 2019-01-26  15054219           0 -0.030159
# 2019-02-02  14585357           0 -0.031145
# 2019-02-09  14753443           0  0.011524
# 2019-02-16  14809032           0  0.003768

# %%
acne_df['returns'].plot()
# Out:
# <AxesSubplot:>

# %%
#Acne Autocorrelation
plot_acf(acne_df['Acne'], lags=40)

# %%
#Acne Partial Autocorrelation
plot_pacf(acne_df['Acne'], zero=False, lags= 40)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#Acne GARCH Model
returns = acne_df['Acne'].pct_change() * 100
returns = returns.dropna()
returns.tail()
# Out:
# 2020-08-01    0.059701
# 2020-08-08    3.420426
# 2020-08-15   -0.419845
# 2020-08-22   -1.604021
# 2020-08-29   -4.336733
# Name: Acne, dtype: float64

# %%
model = arch_model(returns, mean='Zero', vol='GARCH')

# %%
res = model.fit(disp='off')

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   Acne   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.012
# Vol Model:                      GARCH   Log-Likelihood:               -243.904
# Distribution:                  Normal   AIC:                           493.808
# Method:            Maximum Likelihood   BIC:                           501.101
#                                         No. Observations:                   84
# Date:                Sat, Aug 07 2021   Df Residuals:                       84
# Time:                        10:36:13   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          3.2428      1.393      2.328  1.993e-02    [  0.512,  5.973]
# alpha[1]       0.3077      0.172      1.789  7.363e-02 [-2.942e-02,  0.645]
# beta[1]        0.5751      0.120      4.795  1.631e-06    [  0.340,  0.810]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
fig = res.plot(annualize='W')

# %%
#Acne Future forecast 52 weeks
forecast_horizon = 10
forecasts = res.forecast(start='29-AUG-20', horizon=forecast_horizon)
forecasts
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate.head()
# Out:
#                  h.01       h.02       h.03       h.04       h.05       h.06  \
# 2020-08-29  61.081696  64.116043  66.680088  68.864316  70.736508  72.349015
#
#                  h.07       h.08       h.09      h.10
# 2020-08-29  73.743228  74.952479  76.004011  76.92035

# %%
final = intermediate.dropna().T
final
# Out:
#       2020-08-29
# h.01   61.081696
# h.02   64.116043
# h.03   66.680088
# h.04   68.864316
# h.05   70.736508
# h.06   72.349015
# h.07   73.743228
# h.08   74.952479
# h.09   76.004011
# h.10   76.920350

# %%
final.plot()
# Out:
# <AxesSubplot:>

# %%
#ACNE SARIMA Model
model=SARIMAX(endog=acne_df['Acne'], order=(2,1,2),
              seasonal_order=(2,1,2,12),
              trend='c',enforce_invertibility=False
             )
acne_results=model.fit()
print(acne_results.summary())
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               Acne   No. Observations:                   85
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -1092.787
# Date:                            Sat, 07 Aug 2021   AIC                           2205.574
# Time:                                    10:36:29   BIC                           2228.340
# Sample:                                01-19-2019   HQIC                          2214.637
#                                      - 08-29-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1.101e+04      2e+05      0.055      0.956   -3.81e+05    4.03e+05
# ar.L1         -1.2739      0.289     -4.406      0.000      -1.841      -0.707
# ar.L2         -0.7936      0.321     -2.475      0.013      -1.422      -0.165
# ma.L1          1.3058      0.235      5.553      0.000       0.845       1.767
# ma.L2          0.8545      0.271      3.155      0.002       0.324       1.385
# ar.S.L12       0.6657      1.285      0.518      0.604      -1.853       3.185
# ar.S.L24      -0.3059      0.706     -0.433      0.665      -1.690       1.078
# ma.S.L12      -1.0364      1.286     -0.806      0.420      -3.558       1.485
# ma.S.L24       0.3824      1.232      0.310      0.756      -2.033       2.797
# sigma2      1.173e+12      0.024   4.83e+13      0.000    1.17e+12    1.17e+12
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                 3.24
# Prob(Q):                              0.65   Prob(JB):                         0.20
# Heteroskedasticity (H):               2.54   Skew:                            -0.16
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.84e+29. Standard errors may be unstable.
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
acne_results.plot_diagnostics(figsize=(20,10))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#Acne Arima Model
acne_arima_mod = ARIMA(acne_df["Acne"], order=(2,1,2))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'

# %%
acne_arima_results = acne_arima_mod.fit()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:701: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:701: RuntimeWarning: invalid value encountered in true_divide
#   newparams = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:702: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\tsatools.py:702: RuntimeWarning: invalid value encountered in true_divide
#   tmp = ((1-np.exp(-params))/(1+np.exp(-params))).copy()
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '

# %%
acne_arima_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.Acne   No. Observations:                   84
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1241.952
# Method:                       css-mle   S.D. of innovations         623269.201
# Date:                Sat, 07 Aug 2021   AIC                           2495.904
# Time:                        10:36:37   BIC                           2510.488
# Sample:                    01-26-2019   HQIC                          2501.767
#                          - 08-29-2020
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -2.629e+04   5498.154     -4.782      0.000   -3.71e+04   -1.55e+04
# ar.L1.D.Acne     1.2996      0.178      7.296      0.000       0.950       1.649
# ar.L2.D.Acne    -0.5689      0.129     -4.423      0.000      -0.821      -0.317
# ma.L1.D.Acne    -1.4688      0.199     -7.375      0.000      -1.859      -1.078
# ma.L2.D.Acne     0.4688      0.196      2.389      0.017       0.084       0.853
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1422           -0.6732j            1.3258           -0.0848
# AR.2            1.1422           +0.6732j            1.3258            0.0848
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2            2.1332           +0.0000j            2.1332            0.0000
# -----------------------------------------------------------------------------
# """

# %%
acne_arima_results.plot_predict()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
#Lotion Product Sales

# %%
#Decomposing Lotion Data
decomp = sm.tsa.seasonal_decompose(lotion_df['Lotion'],freq=40)
lotion_decomp_data = pd.concat([lotion_df, decomp.trend, decomp.seasonal, decomp.resid], axis=1)
lotion_decomp_data.columns = ['Lotion','lotion_promo', 'trend', 'seasonal', 'resid']

lotion_decomp_data.head()
# Out:
# <ipython-input-342-fb32bc25d940>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomp = sm.tsa.seasonal_decompose(lotion_df['Lotion'],freq=40)
#              Lotion  lotion_promo  trend       seasonal  resid
# 2019-01-05  3227827             0    NaN -318665.059219    NaN
# 2019-01-12  3551875             0    NaN  119273.878281    NaN
# 2019-01-19  3435812             0    NaN -196895.846719    NaN
# 2019-01-26  3406859             0    NaN  -42111.259219    NaN
# 2019-02-02  3754491             0    NaN  404872.640781    NaN

# %%
lotion_decomp_data['seasonal'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_decomp_data['trend'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_decomp_data['resid'].plot()
# Out:
# <AxesSubplot:>

# %%
lotion_noise, lotion_trend = sm.tsa.filters.hpfilter(lotion_df['Lotion'])

# %%
lotion_noise.plot()
# Out:
# <AxesSubplot:>

# %%
lotion_trend.plot()
# Out:
# <AxesSubplot:>

# %%
#ADFuller Test -Seasonal Data is Stationary
result = adfuller(lotion_decomp_data["seasonal"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -3.8250431208140463
# n_lags: 0.0026612364560095678
# p-value: 0.0026612364560095678
# Critial Values:
#    1%, -3.5087828609430614
# Critial Values:
#    5%, -2.895783561573195
# Critial Values:
#    10%, -2.5850381719848565

# %%
# Transform Lotion data to stationary
lotion_df['returns']= lotion_df['Lotion'].pct_change()
lotion_df=lotion_df.dropna()
lotion_df.head()
# Out:
# Date         Lotion  lotion_promo   returns
# 2019-01-12  3551875             0  0.100392
# 2019-01-19  3435812             0 -0.032677
# 2019-01-26  3406859             0 -0.008427
# 2019-02-02  3754491             0  0.102039
# 2019-02-09  3488703             0 -0.070792

# %%
lotion_df['returns'].plot()
# Out:
# <AxesSubplot:>

# %%
plot_acf(lotion_df['Lotion'], lags=40)

# %%
plot_pacf(lotion_df['Lotion'], zero=False, lags= 40)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#Lotion Garch Model
lotion_returns = lotion_df['Lotion'].pct_change() * 100
lotion_returns = lotion_returns.dropna()
lotion_returns.tail()
# Out:
# 2020-08-01   -1.777311
# 2020-08-08    4.128402
# 2020-08-15    4.991345
# 2020-08-22   -1.714548
# 2020-08-29   -3.216952
# Name: Lotion, dtype: float64

# %%
lotion_model = arch_model(lotion_returns, mean='Zero', vol='GARCH')

# %%
lotion_res = lotion_model.fit(disp='off')

# %%
lotion_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Lotion   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.012
# Vol Model:                      GARCH   Log-Likelihood:               -286.561
# Distribution:                  Normal   AIC:                           579.122
# Method:            Maximum Likelihood   BIC:                           586.450
#                                         No. Observations:                   85
# Date:                Sat, Aug 07 2021   Df Residuals:                       85
# Time:                        10:36:57   Df Model:                            0
#                               Volatility Model
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# omega          5.5113      5.244      1.051      0.293    [ -4.766, 15.789]
# alpha[1]       0.2072      0.107      1.930  5.362e-02 [-3.227e-03,  0.418]
# beta[1]        0.7014      0.119      5.899  3.647e-09    [  0.468,  0.934]
# ===========================================================================
#
# Covariance estimator: robust
# """

# %%
#Lotion Sales Volatility
lotion_fig = lotion_res.plot(annualize='W')

# %%
forecast_horizon = 10
lotion_forecasts = lotion_res.forecast(start='29-AUG-20', horizon=forecast_horizon)
lotion_forecasts
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
lotion_intermediate = np.sqrt(lotion_forecasts.variance.dropna() * 252)
lotion_intermediate.head()
# Out:
#                  h.01       h.02       h.03       h.04       h.05      h.06  \
# 2020-08-29  81.926835  86.530354  90.510405  93.980719  97.026349  99.71304
#
#                   h.07        h.08        h.09        h.10
# 2020-08-29  102.092932  104.208232  106.093672  107.778225

# %%
lotion_final = lotion_intermediate.dropna().T
lotion_final
# Out:
#       2020-08-29
# h.01   81.926835
# h.02   86.530354
# h.03   90.510405
# h.04   93.980719
# h.05   97.026349
# h.06   99.713040
# h.07  102.092932
# h.08  104.208232
# h.09  106.093672
# h.10  107.778225

# %%
lotion_final.plot()
# Out:
# <AxesSubplot:>

# %%
#Lotion SARIMA Model
lotion_sar_model=SARIMAX(endog=lotion_df['Lotion'], order=(2,1,2),
              seasonal_order=(2,1,2,12),
              trend='c',enforce_invertibility=False
             )
lotion_results=lotion_sar_model.fit()
print(lotion_results.summary())
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             Lotion   No. Observations:                   86
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -1027.664
# Date:                            Sat, 07 Aug 2021   AIC                           2075.329
# Time:                                    10:37:05   BIC                           2098.233
# Sample:                                01-12-2019   HQIC                          2084.456
#                                      - 08-29-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   7640.2162   1.63e+04      0.468      0.640   -2.44e+04    3.96e+04
# ar.L1          1.2951      0.326      3.975      0.000       0.657       1.934
# ar.L2         -0.8015      0.355     -2.255      0.024      -1.498      -0.105
# ma.L1         -1.2257      0.422     -2.905      0.004      -2.053      -0.399
# ma.L2          0.6948      0.424      1.639      0.101      -0.136       1.526
# ar.S.L12      -0.4625      0.600     -0.771      0.441      -1.639       0.714
# ar.S.L24       0.3884      0.354      1.096      0.273      -0.306       1.083
# ma.S.L12       0.1272      0.618      0.206      0.837      -1.085       1.339
# ma.S.L24      -0.7533      0.536     -1.406      0.160      -1.803       0.297
# sigma2      1.209e+11      0.003   4.09e+13      0.000    1.21e+11    1.21e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.15
# Prob(Q):                              0.90   Prob(JB):                         0.93
# Heteroskedasticity (H):               1.60   Skew:                            -0.06
# Prob(H) (two-sided):                  0.26   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.48e+29. Standard errors may be unstable.

# %%
lotion_results.plot_diagnostics(figsize=(20,10))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#Lotion ARIMA Model
lotion_arima_mod = ARIMA(lotion_df["Lotion"], order=(2,1,2))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'

# %%
lotion_arima_results = lotion_arima_mod.fit()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:547: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '

# %%
lotion_arima_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D.Lotion   No. Observations:                   85
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1179.899
# Method:                       css-mle   S.D. of innovations         254329.642
# Date:                Sat, 07 Aug 2021   AIC                           2371.798
# Time:                        10:37:07   BIC                           2386.454
# Sample:                    01-19-2019   HQIC                          2377.693
#                          - 08-29-2020
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -4037.6594   5467.973     -0.738      0.460   -1.48e+04    6679.370
# ar.L1.D.Lotion     0.0563      0.110      0.513      0.608      -0.159       0.272
# ar.L2.D.Lotion     0.6035      0.108      5.577      0.000       0.391       0.816
# ma.L1.D.Lotion    -0.0753      0.063     -1.197      0.231      -0.198       0.048
# ma.L2.D.Lotion    -0.9247      0.061    -15.083      0.000      -1.045      -0.805
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2414           +0.0000j            1.2414            0.0000
# AR.2           -1.3348           +0.0000j            1.3348            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2           -1.0814           +0.0000j            1.0814            0.5000
# -----------------------------------------------------------------------------
# """

# %%
#Lotion Future Forecast Predict ARIMA
lotion_arima_results.plot_predict()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
#Makeup Product Sales
makeup_df
# Out:
# Date         Makeup makeup_promo
# 2019-01-05  7156661            0
# 2019-01-12  7188663            0
# 2019-01-19  7173238            0
# 2019-01-26  6851425            0
# 2019-02-02  6745738            0
# ...             ...          ...
# 2020-08-01  5422756            1
# 2020-08-08  5647887            1
# 2020-08-15  5619787            1
# 2020-08-22  5622940            1
# 2020-08-29  3488149            1
#
# [87 rows x 2 columns]

# %%
#Decomposing Makeup Data
decomp = sm.tsa.seasonal_decompose(makeup_df['Makeup'],freq=40)
makeup_decomp_data = pd.concat([makeup_df, decomp.trend, decomp.seasonal, decomp.resid], axis=1)
makeup_decomp_data.columns = ['Makeup','makeup_promo', 'trend', 'seasonal', 'resid']
# Out:
# <ipython-input-370-9b68dd61a79a>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomp = sm.tsa.seasonal_decompose(makeup_df['Makeup'],freq=40)

# %%
makeup_decomp_data.head()
# Out:
#              Makeup makeup_promo  trend       seasonal  resid
# 2019-01-05  7156661            0    NaN -397333.866406    NaN
# 2019-01-12  7188663            0    NaN -352499.741406    NaN
# 2019-01-19  7173238            0    NaN -314075.978906    NaN
# 2019-01-26  6851425            0    NaN -184717.816406    NaN
# 2019-02-02  6745738            0    NaN  -44181.741406    NaN

# %%
makeup_decomp_data['seasonal'].plot()
# Out:
# <AxesSubplot:>

# %%
makeup_decomp_data['trend'].plot()
# Out:
# <AxesSubplot:>

# %%
makeup_decomp_data['resid'].plot()
# Out:
# <AxesSubplot:>

# %%
#Makeup Noise and Trend
makeup_noise, makeup_trend = sm.tsa.filters.hpfilter(makeup_df['Makeup'])

# %%
makeup_noise.plot()
# Out:
# <AxesSubplot:>

# %%
makeup_trend.plot()
# Out:
# <AxesSubplot:>

# %%
#ADFuller Test -Seasonal Data is Stationary Makeup Seasonal Data
result = adfuller(makeup_decomp_data["seasonal"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -3.340502233576264
# n_lags: 0.013162286878336982
# p-value: 0.013162286878336982
# Critial Values:
#    1%, -3.5219803175527606
# Critial Values:
#    5%, -2.9014701097664504
# Critial Values:
#    10%, -2.58807215485756

# %%
#Transform Makeup Data into Stationary Data
makeup_df['returns']= makeup_df['Makeup'].pct_change()
makeup_df=makeup_df.dropna()
makeup_df.head()
# Out:
# Date         Makeup makeup_promo   returns
# 2019-01-12  7188663            0  0.004472
# 2019-01-19  7173238            0 -0.002146
# 2019-01-26  6851425            0 -0.044863
# 2019-02-02  6745738            0 -0.015426
# 2019-02-09  7142905            0  0.058877

# %%
makeup_df['returns'].plot()
# Out:
# <AxesSubplot:>

# %%
#Makeup Autocorrelation
plot_acf(makeup_df['Makeup'], lags=40)

# %%
plot_pacf(makeup_df['Makeup'], zero=False, lags=40)

# %%
#Makeup Garch Results
makeup_garch_returns = makeup_df['Makeup'].pct_change() * 100
makeup_garch_returns = makeup_garch_returns.dropna()
makeup_garch_returns.tail()
# Out:
# 2020-08-01     1.269370
# 2020-08-08     4.151597
# 2020-08-15    -0.497531
# 2020-08-22     0.056105
# 2020-08-29   -37.965744
# Name: Makeup, dtype: float64

# %%
model = arch_model(makeup_garch_returns, mean='Zero', vol='GARCH', p=1, q=1)

# %%
res = model.fit(disp='off')

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                 Makeup   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.012
# Vol Model:                      GARCH   Log-Likelihood:               -282.686
# Distribution:                  Normal   AIC:                           571.372
# Method:            Maximum Likelihood   BIC:                           578.700
#                                         No. Observations:                   85
# Date:                Sat, Aug 07 2021   Df Residuals:                       85
# Time:                        10:37:28   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega          0.8844      2.103      0.421      0.674      [ -3.237,  5.006]
# alpha[1]       0.0000  4.555e-02      0.000      1.000 [-8.927e-02,8.927e-02]
# beta[1]        1.0000  3.665e-02     27.286 6.180e-164      [  0.928,  1.072]
# =============================================================================
#
# Covariance estimator: robust
# """

# %%
#Makeup Sales Volatility
fig = res.plot(annualize='W')

# %%
forecast_horizon = 10
forecasts = res.forecast(start='29-AUG-20', horizon=forecast_horizon)
forecasts
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\arch\__future__\_utility.py:11: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   warnings.warn(

# %%
intermediate = np.sqrt(forecasts.variance.dropna() * 52)
intermediate.head()
# Out:
#                  h.01       h.02       h.03       h.04       h.05       h.06  \
# 2020-08-29  69.618513  69.948012  70.275967  70.602398  70.927326  71.250773
#
#                  h.07       h.08       h.09       h.10
# 2020-08-29  71.572759  71.893302  72.212422  72.530138

# %%
final = intermediate.dropna().T
final
# Out:
#       2020-08-29
# h.01   69.618513
# h.02   69.948012
# h.03   70.275967
# h.04   70.602398
# h.05   70.927326
# h.06   71.250773
# h.07   71.572759
# h.08   71.893302
# h.09   72.212422
# h.10   72.530138

# %%
final.plot()
# Out:
# <AxesSubplot:>

# %%
#SARIMA Analysis
makeup_model=SARIMAX(endog=makeup_df['Makeup'].astype('float'), order=(2,1,2),
              seasonal_order=(2,1,2,12),
              trend='c',enforce_invertibility=False
             )
makeup_results=makeup_model.fit()
print(makeup_results.summary())
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-SAT will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             Makeup   No. Observations:                   86
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -1073.198
# Date:                            Sat, 07 Aug 2021   AIC                           2166.396
# Time:                                    10:37:37   BIC                           2189.300
# Sample:                                01-12-2019   HQIC                          2175.524
#                                      - 08-29-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept  -2.875e+04   5.24e+04     -0.548      0.583   -1.32e+05     7.4e+04
# ar.L1          1.1764      0.737      1.597      0.110      -0.268       2.620
# ar.L2         -0.6347      0.747     -0.850      0.395      -2.098       0.829
# ma.L1         -1.0608      0.824     -1.287      0.198      -2.676       0.554
# ma.L2          0.4947      0.799      0.620      0.536      -1.070       2.060
# ar.S.L12      -0.5433      1.373     -0.396      0.692      -3.235       2.149
# ar.S.L24       0.3046      0.610      0.499      0.617      -0.891       1.500
# ma.S.L12       0.0962      1.396      0.069      0.945      -2.640       2.833
# ma.S.L24      -0.7298      1.188     -0.614      0.539      -3.058       1.599
# sigma2      4.173e+11      0.002   1.95e+14      0.000    4.17e+11    4.17e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.67   Jarque-Bera (JB):                26.28
# Prob(Q):                              0.20   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.55   Skew:                            -0.48
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.42e+30. Standard errors may be unstable.
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#Makeup SARIMA Diagnostic
makeup_results.plot_diagnostics(figsize=(20,10))
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
#Makeup ARIMA model
makeup_model = ARIMA(makeup_df['Makeup'].values, order=(2, 1, 2))
makeup_results = makeup_model.fit()
makeup_results.summary()
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                   85
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1232.408
# Method:                       css-mle   S.D. of innovations         466882.083
# Date:                Sat, 07 Aug 2021   AIC                           2476.816
# Time:                        10:37:38   BIC                           2491.472
# Sample:                             1   HQIC                          2482.711
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.354e+04   6.17e+04     -0.705      0.481   -1.65e+05    7.75e+04
# ar.L1.D.y     -0.8066      0.112     -7.213      0.000      -1.026      -0.587
# ar.L2.D.y     -0.6786      0.089     -7.649      0.000      -0.852      -0.505
# ma.L1.D.y      1.0342      0.066     15.569      0.000       0.904       1.164
# ma.L2.D.y      0.9997      0.095     10.480      0.000       0.813       1.187
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5944           -1.0585j            1.2139           -0.3314
# AR.2           -0.5944           +1.0585j            1.2139            0.3314
# MA.1           -0.5172           -0.8560j            1.0001           -0.3365
# MA.2           -0.5172           +0.8560j            1.0001            0.3365
# -----------------------------------------------------------------------------
# """

# %%
#Makeup Future Predict
makeup_results.plot_predict()

# %%
# Determing if week of the year affect sales.

# %%
X = acne_df['Acne'].to_frame()

# %%
# Generate a column with the week of the year
X['Week_of_Year'] = X.index.weekofyear
X.head()
# Out:
# <ipython-input-398-0d8505e88685>:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   X['Week_of_Year'] = X.index.weekofyear
#                 Acne  Week_of_Year
# 2019-01-19  15522357             3
# 2019-01-26  15054219             4
# 2019-02-02  14585357             5
# 2019-02-09  14753443             6
# 2019-02-16  14809032             7

# %%
acne_week=X.copy()

# %%
X.plot(x= "Week_of_Year", y="Acne", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Week_of_Year', ylabel='Acne'>

# %%
# Binary encode the weekly column to use as new input features for the model
X_binary_encoded = pd.get_dummies(X, columns=['Week_of_Year'])
X_binary_encoded.head()
# Out:
#                 Acne  Week_of_Year_1  Week_of_Year_2  Week_of_Year_3  \
# 2019-01-19  15522357               0               0               1
# 2019-01-26  15054219               0               0               0
# 2019-02-02  14585357               0               0               0
# 2019-02-09  14753443               0               0               0
# 2019-02-16  14809032               0               0               0
#
#             Week_of_Year_4  Week_of_Year_5  Week_of_Year_6  Week_of_Year_7  \
# 2019-01-19               0               0               0               0
# 2019-01-26               1               0               0               0
# 2019-02-02               0               1               0               0
# 2019-02-09               0               0               1               0
# 2019-02-16               0               0               0               1
#
#             Week_of_Year_8  Week_of_Year_9  ...  Week_of_Year_43  \
# 2019-01-19               0               0  ...                0
# 2019-01-26               0               0  ...                0
# 2019-02-02               0               0  ...                0
# 2019-02-09               0               0  ...                0
# 2019-02-16               0               0  ...                0
#
#             Week_of_Year_44  Week_of_Year_45  Week_of_Year_46  \
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
#             Week_of_Year_47  Week_of_Year_48  Week_of_Year_49  \
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
#             Week_of_Year_50  Week_of_Year_51  Week_of_Year_52
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
# [5 rows x 53 columns]

# %%
# The Acne Sales column must be deleted from the input features
X_binary_encoded = X_binary_encoded.drop('Acne', axis=1)
X_binary_encoded.head()
# Out:
#             Week_of_Year_1  Week_of_Year_2  Week_of_Year_3  Week_of_Year_4  \
# 2019-01-19               0               0               1               0
# 2019-01-26               0               0               0               1
# 2019-02-02               0               0               0               0
# 2019-02-09               0               0               0               0
# 2019-02-16               0               0               0               0
#
#             Week_of_Year_5  Week_of_Year_6  Week_of_Year_7  Week_of_Year_8  \
# 2019-01-19               0               0               0               0
# 2019-01-26               0               0               0               0
# 2019-02-02               1               0               0               0
# 2019-02-09               0               1               0               0
# 2019-02-16               0               0               1               0
#
#             Week_of_Year_9  Week_of_Year_10  ...  Week_of_Year_43  \
# 2019-01-19               0                0  ...                0
# 2019-01-26               0                0  ...                0
# 2019-02-02               0                0  ...                0
# 2019-02-09               0                0  ...                0
# 2019-02-16               0                0  ...                0
#
#             Week_of_Year_44  Week_of_Year_45  Week_of_Year_46  \
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
#             Week_of_Year_47  Week_of_Year_48  Week_of_Year_49  \
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
#             Week_of_Year_50  Week_of_Year_51  Week_of_Year_52
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
# 2019-02-16                0                0                0
#
# [5 rows x 52 columns]

# %%
# The target for our model is to predict the Acne Sales
y = acne_df['Acne'].copy()

# %%
# Create the Linear Regression model
model = LinearRegression()

# Fit the model to the data (Train the model)
model.fit(X_binary_encoded, y)

# Predict the sales using the week of the year as inputs
predictions = model.predict(X_binary_encoded)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# The default scoring method is the R2 score
score = model.score(X_binary_encoded, y)
r2 = r2_score(y, predictions)

print(f"Score: {score}, r2: {r2}")
# Out:
# Score: 0.3961351720142927, r2: 0.3961351720142927

# %%
# Mean Squared Error
mse = mean_squared_error(y, predictions)
mse
# Out:
# 710645642013.0353

# %%
# Root Mean Squared Error
rmse = np.sqrt(mse)
rmse
# Out:
# 842998.008309056

# %%
# Standard deviation
np.std(y)
# Out:
# 1084817.4964459406

# %%
plt.scatter(X['Week_of_Year'], y)
plt.plot(X['Week_of_Year'], predictions, color='red')

# %%
### This graph and R2 shows that we can only predict the sales based on what week of the year with a 39 % accuracy.

# %%
## Re Running for Makeup as it is the second largest to

# %%
X = makeup_df['Makeup'].to_frame()

# %%
# Generate a column with the week of the year
X['Week_of_Year'] = X.index.weekofyear
X.head()
# Out:
# <ipython-input-412-0d8505e88685>:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   X['Week_of_Year'] = X.index.weekofyear
#              Makeup  Week_of_Year
# 2019-01-12  7188663             2
# 2019-01-19  7173238             3
# 2019-01-26  6851425             4
# 2019-02-02  6745738             5
# 2019-02-09  7142905             6

# %%
makeup_week=X.copy()

# %%
X.plot(x= "Week_of_Year", y="Makeup", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Week_of_Year', ylabel='Makeup'>

# %%
X_binary_encoded = pd.get_dummies(X, columns=['Week_of_Year'])
X_binary_encoded = X_binary_encoded.drop('Makeup', axis=1)

# %%
y = makeup_df['Makeup'].copy()

# %%
# Create the Linear Regression model
model = LinearRegression()

# Fit the model to the data (Train the model)
model.fit(X_binary_encoded, y)

# Predict the sales using the week of the year as inputs
predictions = model.predict(X_binary_encoded)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# The default scoring method is the R2 score
score = model.score(X_binary_encoded, y)
r2 = r2_score(y, predictions)

print(f"Score: {score}, r2: {r2}")
# Out:
# Score: 0.3099955354299515, r2: 0.3099955354299515

# %%
# Mean Squared Error
mse = mean_squared_error(y, predictions)
mse
# Out:
# 1008671015095.1046

# %%
plt.scatter(X['Week_of_Year'], y)
plt.plot(X['Week_of_Year'], predictions, color='red')

# %%
## Now trying Lotion data

# %%
X = lotion_df['Lotion'].to_frame()

# %%
# Generate a column with the week of the year
X['Week_of_Year'] = X.index.weekofyear
X.head()
# Out:
# <ipython-input-423-0d8505e88685>:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   X['Week_of_Year'] = X.index.weekofyear
#              Lotion  Week_of_Year
# 2019-01-12  3551875             2
# 2019-01-19  3435812             3
# 2019-01-26  3406859             4
# 2019-02-02  3754491             5
# 2019-02-09  3488703             6

# %%
X.plot(x= "Week_of_Year", y="Lotion", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Week_of_Year', ylabel='Lotion'>

# %%
# Binary encode the weekly column to use as new input features for the model
X_binary_encoded = pd.get_dummies(X, columns=['Week_of_Year'])
X_binary_encoded.head()
# Out:
#              Lotion  Week_of_Year_1  Week_of_Year_2  Week_of_Year_3  \
# 2019-01-12  3551875               0               1               0
# 2019-01-19  3435812               0               0               1
# 2019-01-26  3406859               0               0               0
# 2019-02-02  3754491               0               0               0
# 2019-02-09  3488703               0               0               0
#
#             Week_of_Year_4  Week_of_Year_5  Week_of_Year_6  Week_of_Year_7  \
# 2019-01-12               0               0               0               0
# 2019-01-19               0               0               0               0
# 2019-01-26               1               0               0               0
# 2019-02-02               0               1               0               0
# 2019-02-09               0               0               1               0
#
#             Week_of_Year_8  Week_of_Year_9  ...  Week_of_Year_43  \
# 2019-01-12               0               0  ...                0
# 2019-01-19               0               0  ...                0
# 2019-01-26               0               0  ...                0
# 2019-02-02               0               0  ...                0
# 2019-02-09               0               0  ...                0
#
#             Week_of_Year_44  Week_of_Year_45  Week_of_Year_46  \
# 2019-01-12                0                0                0
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
#
#             Week_of_Year_47  Week_of_Year_48  Week_of_Year_49  \
# 2019-01-12                0                0                0
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
#
#             Week_of_Year_50  Week_of_Year_51  Week_of_Year_52
# 2019-01-12                0                0                0
# 2019-01-19                0                0                0
# 2019-01-26                0                0                0
# 2019-02-02                0                0                0
# 2019-02-09                0                0                0
#
# [5 rows x 53 columns]

# %%
# The Acne Sales column must be deleted from the input features
X_binary_encoded = X_binary_encoded.drop("Lotion", axis=1)

# %%
y = lotion_df['Lotion'].copy()

# %%
# Create the Linear Regression model
model = LinearRegression()

# Fit the model to the data (Train the model)
model.fit(X_binary_encoded, y)

# Predict the sales using the week of the year as inputs
predictions = model.predict(X_binary_encoded)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# The default scoring method is the R2 score
score = model.score(X_binary_encoded, y)
r2 = r2_score(y, predictions)

print(f"Score: {score}, r2: {r2}")
# Out:
# Score: 0.7650214461578784, r2: 0.7650214461578784

# %%
# Mean Squared Error
mse = mean_squared_error(y, predictions)
mse
# Out:
# 48981808600.19768

# %%
plt.scatter(X['Week_of_Year'], y)
plt.plot(X['Week_of_Year'], predictions, color='red')

# %%
## The Lotion was the strongest model with 76% model fit for having the week predict the sales outcome

# %%
### Now trying to determine if promos effect sales using A/B Testing ###

# %%
### Code below implementeed from https://harvard-iacs.github.io/2018-CS109A/lectures/lecture-23/demo/ ###

# %%
# H(NULL)=The Promos have no effect on sales
# H1== Promos have an effect on sales price

# %%
## ACNE TEST

# %%
acne_df=acne_df.astype(int)
acne_df1=acne_df.dropna()

# %%
#creating the sales and promo measures for each group
controlgroup = acne_df1['Acne'][acne_df1['acne_promo']==0]
trt1group = acne_df1['Acne'][acne_df1['acne_promo']==1]

# %%
# The two-sample t-test is used to test whether the unknown means of two groups are equal or not.

# %%
#two sample t-test testing promo and non promo group
sp.stats.ttest_ind(controlgroup,trt1group)
# Out:
# Ttest_indResult(statistic=1.7176035531402944, pvalue=0.08959796000148233)

# %%
#ANOVA F-test
sp.stats.f_oneway(controlgroup,trt1group)
# Out:
# F_onewayResult(statistic=2.9501619657601736, pvalue=0.08959796000148157)

# %%
## P <.05 so we reject the NULL Hyptohesis and conclude that promos are affecting sales performance.

# %%
##insert graph here

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)


p_bp_male = plt.hist(acne_df1['Acne'][acne_df1['acne_promo']==0], label= "Non-Promos",color="red",
                     density= True,
                     alpha=0.75)
p_bp_female = plt.hist(acne_df1['Acne'][acne_df1['acne_promo']==1], label= "Promos",color="blue",
                       density= True,
                       alpha=0.75)


plt.suptitle("Promo vs. Non- Promo Sales", fontsize= 20)
plt.xlabel("Sales", fontsize= 16)
plt.ylabel("Probability density", fontsize= 16)



plt.show()

# %%
##Using Makeup

# %%
#creating the sales and promo measures for each group
controlgroup = makeup_df['Makeup'][makeup_df['makeup_promo']==0]
trt1group = makeup_df['Makeup'][makeup_df['makeup_promo']==1]

# %%
#two sample t-test testing promo and non promo group
sp.stats.ttest_ind(controlgroup,trt1group)
# Out:
# Ttest_indResult(statistic=9.230482222533691, pvalue=2.038730579778468e-14)

# %%
#ANOVA F-test
sp.stats.f_oneway(controlgroup,trt1group)
# Out:
# F_onewayResult(statistic=85.20180206051043, pvalue=2.0387305797785047e-14)

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)


p_bp_male = plt.hist(makeup_df['Makeup'][makeup_df['makeup_promo']==0], label= "Non-Promos",color="red",
                     density= True,
                     alpha=0.75)
p_bp_female = plt.hist(makeup_df['Makeup'][makeup_df['makeup_promo']==1], label= "Promos",color="blue",
                       density= True,
                       alpha=0.75)


plt.suptitle("Promo vs. Non- Promo Sales", fontsize= 20)
plt.xlabel("Sales", fontsize= 16)
plt.ylabel("Probability density", fontsize= 16)



plt.show()

# %%
## Using Lotion

# %%
#creating the sales and promo measures for each group
controlgroup = lotion_df['Lotion'][lotion_df['lotion_promo']==0]
trt1group = lotion_df['Lotion'][lotion_df['lotion_promo']==1]

# %%
#two sample t-test testing promo and non promo group
sp.stats.ttest_ind(controlgroup,trt1group)
# Out:
# Ttest_indResult(statistic=-1.6870489949189498, pvalue=0.09530436726594935)

# %%
#ANOVA F-test
sp.stats.f_oneway(controlgroup,trt1group)
# Out:
# F_onewayResult(statistic=2.8461343112570394, pvalue=0.09530436726594926)

# %%
fig = plt.figure(figsize= (20, 10))
ax = fig.add_subplot(111)


p_bp_male = plt.hist(lotion_df['Lotion'][lotion_df['lotion_promo']==0], label= "Non-Promos",color="red",
                     density= True,
                     alpha=0.75)
p_bp_female = plt.hist(lotion_df['Lotion'][lotion_df['lotion_promo']==1], label= "Promos",color="blue",
                       density= True,
                       alpha=0.75)


plt.suptitle("Promo vs. Non- Promo Sales", fontsize= 20)
plt.xlabel("Sales", fontsize= 16)
plt.ylabel("Probability density", fontsize= 16)



plt.show()

# %%
## Running SVR Prediction on Acne Sales prices

# %%
acne_df.head()
# Out:
# Date            Acne  acne_promo  returns
# 2019-01-19  15522357           0        0
# 2019-01-26  15054219           0        0
# 2019-02-02  14585357           0        0
# 2019-02-09  14753443           0        0
# 2019-02-16  14809032           0        0

# %%
X = acne_df.iloc[:,0].values     
y = acne_df.iloc[:,1].values

# %%
# split the dataset into test set and train set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=None)

# %%
X_train[:10]
# some features are big in scale, so adjust the scale
# Out:
# array([15697616, 13517117, 16056085, 14862856, 13697476, 14913296,
#        17497769, 13791322, 16148805, 13103453])

# %%
 X_train= X_train.reshape(-1,1)
 y_train= y_train.reshape(-1,1)
 X_test = X_test.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from collections import Counter
from imblearn.over_sampling import SMOTENC

# %%
# PAY ATTENTION, WE ARE IMPORTING SVR, WHICH IS FOR REGRESSION
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf') # using rbf kernel
# also, we here call it a regressor, since it is a regression

# in SVC = support vector classification, many name it as a classifier

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %%
predictions = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.6930589373046533

# %%
r2_score(y_test,predictions)
# Out:
# -0.9830795653857172

# %%
# Visualising the Regression results
plt.scatter(y_test, predictions, color = 'red')
plt.plot(y_test, predictions, color = 'blue')
plt.title('Predictions by Week of Year')
plt.xlabel('Test Week')
plt.ylabel('Predicted Week')
plt.show()

# %%
## Outsput shows that the model is only 8.2% accurate in prediction.

# %%
##Using Makeup

# %%
makeup_df.head()
# Out:
# Date         Makeup makeup_promo   returns  Week
# 2019-01-12  7188663            0  0.004472     2
# 2019-01-19  7173238            0 -0.002146     3
# 2019-01-26  6851425            0 -0.044863     4
# 2019-02-02  6745738            0 -0.015426     5
# 2019-02-09  7142905            0  0.058877     6

# %%
# makeup_df.drop(columns="makeup_promo")

# %%
makeup_df['Week'] = makeup_df.index.weekofyear
# Out:
# <ipython-input-537-17e265cee42f>:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   makeup_df['Week'] = makeup_df.index.weekofyear
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
makeup_df.head()
# Out:
# Date         Makeup makeup_promo   returns  Week
# 2019-01-12  7188663            0  0.004472     2
# 2019-01-19  7173238            0 -0.002146     3
# 2019-01-26  6851425            0 -0.044863     4
# 2019-02-02  6745738            0 -0.015426     5
# 2019-02-09  7142905            0  0.058877     6

# %%
# makeup_df.drop(columns="makeup_promo")

# %%
X = makeup_df.iloc[:,2].values     
y = makeup_df.iloc[:,1].values

# %%
# split the dataset into test set and train set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
X_train[:10]
# some features are big in scale, so adjust the scale
# Out:
# array([ 0.05762076,  0.01448125,  0.01762633, -0.01242969, -0.06105223,
#        -0.01080406,  0.03377657,  0.01145184, -0.24221042,  0.08390704])

# %%
X_train= X_train.reshape(-1,1)
y_train= y_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

# %%
# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()
# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)

# %%
# PAY ATTENTION, WE ARE IMPORTING SVR, WHICH IS FOR REGRESSION
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf') # using rbf kernel
# also, we here call it a regressor, since it is a regression

# in SVC = support vector classification, many name it as a classifier

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %%
predictions = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.4724966240990759

# %%
r2_score(y_test,predictions)
# Out:
# -0.004638769032605516

# %%
# Visualising the Regression results
plt.scatter(y_test, predictions, color = 'red')
plt.plot(y_test, predictions, color = 'blue')
plt.title('Predictions by Week of Year')
plt.xlabel('Test Week')
plt.ylabel('Predicted Week')
plt.show()

# %%
## Using Lotion

# %%
lotion_df['Week'] = makeup_df.index.weekofyear
# Out:
# <ipython-input-553-ddc723731459>:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   lotion_df['Week'] = makeup_df.index.weekofyear

# %%
lotion_df.head()
# Out:
# Date         Lotion  lotion_promo   returns  Week
# 2019-01-12  3551875             0  0.100392     2
# 2019-01-19  3435812             0 -0.032677     3
# 2019-01-26  3406859             0 -0.008427     4
# 2019-02-02  3754491             0  0.102039     5
# 2019-02-09  3488703             0 -0.070792     6

# %%
lotion_df.drop(columns="lotion_promo")
# Out:
# Date         Lotion   returns  Week
# 2019-01-12  3551875  0.100392     2
# 2019-01-19  3435812 -0.032677     3
# 2019-01-26  3406859 -0.008427     4
# 2019-02-02  3754491  0.102039     5
# 2019-02-09  3488703 -0.070792     6
# ...             ...       ...   ...
# 2020-08-01  2693439 -0.017773    31
# 2020-08-08  2804635  0.041284    32
# 2020-08-15  2944624  0.049913    33
# 2020-08-22  2894137 -0.017145    34
# 2020-08-29  2801034 -0.032170    35
#
# [86 rows x 3 columns]

# %%
X = lotion_df.iloc[:,0].values     
y = lotion_df.iloc[:,1].values

# %%
# split the dataset into test set and train set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
X_train[:3]
# Out:
# array([3236759, 3739085, 2941523])

# %%
X_train= X_train.reshape(-1,1)
y_train= y_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
from sklearn.svm import SVR

# %%
regressor = SVR(kernel = 'rbf')

# %%
regressor.fit(X_train, y_train)
# Out:
# C:\Users\Dev\Anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %%
predictions = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
rmse
# Out:
# 0.6957659523172272

# %%
r2_score(y_test,predictions)
# Out:
# -1.0369512255956232

# %%
# Visualising the Regression results
plt.scatter(y_test, predictions, color = 'red')
plt.plot(y_test, predictions, color = 'blue')
plt.title('Predictions by Week of Year')
plt.xlabel('Test Week')
plt.ylabel('Predicted Week')
plt.show()

# %%
###LTSM Predictions  Acne

# %%
acne_df.drop(columns="returns")
# Out:
# Date            Acne  acne_promo
# 2019-01-19  15522357           0
# 2019-01-26  15054219           0
# 2019-02-02  14585357           0
# 2019-02-09  14753443           0
# 2019-02-16  14809032           0
# ...              ...         ...
# 2020-08-01  13517117           0
# 2020-08-08  13979460           0
# 2020-08-15  13920768           0
# 2020-08-22  13697476           0
# 2020-08-29  13103453           0
#
# [85 rows x 2 columns]

# %%
df=acne_df.copy()

# %%
# This function accepts the column number for the features (X) and the target (y)
# It chunks the data up with a rolling window of Xt-n to predict Xt
# It returns a numpy array of X any y
def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Sales prices using a 10 day window of previous sales

window_size = 6
# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 1
target_column = 0
X, y = window_data(df, window_size, feature_column, target_column)

# %%
# Use 70% of the data for training and the remaineder for testing
from sklearn.model_selection import train_test_split

split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
from sklearn.preprocessing import MinMaxScaler
# Use the MinMaxScaler to scale data between 0 and 1.
scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Build the LSTM model.

# %%
model = Sequential()

number_units = 5 # The number of units in each LSTM layer, is equal to the size of the time window
dropout_fraction = 0.2 # fraction of nodes that will be dropped on each epoch. randomly drop 20% of the units.

# Model set-up
number_input_features = 20
hidden_nodes_layer1 = 5
hidden_nodes_layer2 = 5


# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 6, 5)              140
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 5)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 6, 5)              220
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 5)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 586
# Trainable params: 586
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model


model.fit(X_train, y_train, epochs =10, shuffle = False, batch_size=1, verbose=1 )
# Out:
# Epoch 1/10
# 54/54 [==============================] - 2s 3ms/step - loss: 0.2447
# Epoch 2/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1210
# Epoch 3/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0788
# Epoch 4/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0586
# Epoch 5/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0515
# Epoch 6/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0411
# Epoch 7/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0305
# Epoch 8/10
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0392
# Epoch 9/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0430
# Epoch 10/10
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0348

# %%
# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 1s 623ms/step - loss: 0.0742
# 0.0741690993309021

# %%
# Make some predictions
predicted= model.predict(X_test)

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Real Sales": real_prices.ravel(),
    "Predicted Sales": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#             Real Sales  Predicted Sales
# 2020-03-21  17445158.0       15058982.0
# 2020-03-28  15644868.0       15058982.0
# 2020-04-04  12345392.0       15058982.0
# 2020-04-11  12329168.0       15058982.0
# 2020-04-18  11968714.0       15058982.0

# %%
stocks.plot()  ## Acne
# Out:
# <AxesSubplot:>

# %%
##Testing with Lotion

# %%
df=lotion_df

# %%
window_size = 6
# Column index 0 is the 'fng_value' column
# Column index 1 is the `Close` column
feature_column = 1
target_column = 0
X, y = window_data(df, window_size, feature_column, target_column)

# %%
from sklearn.model_selection import train_test_split

split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %%
scaler = MinMaxScaler()
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
scaler.fit(y)
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential()

number_units = 5 # The number of units in each LSTM layer, is equal to the size of the time window
dropout_fraction = 0.2 # fraction of nodes that will be dropped on each epoch. randomly drop 20% of the units.

# Model set-up
number_input_features = 20
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 10


# Layer 1
model.add(LSTM(
    units=number_units,
    return_sequences=True,
    input_shape=(X_train.shape[1], 1))
    )
model.add(Dropout(dropout_fraction))
# Layer 2
model.add(LSTM(units=number_units, return_sequences=True))
model.add(Dropout(dropout_fraction))
# Layer 3
model.add(LSTM(units=number_units))
model.add(Dropout(dropout_fraction))
# Output layer
model.add(Dense(1))

# %%
# Compile the model
model.compile(optimizer="adam", loss = "mean_squared_error")

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 6, 5)              140
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 5)              0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 6, 5)              220
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 5)              0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 5)                 220
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 586
# Trainable params: 586
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs =10, shuffle = False, batch_size=1, verbose=1 )
# Out:
# Epoch 1/10
# 55/55 [==============================] - 2s 3ms/step - loss: 0.0709
# Epoch 2/10
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0462
# Epoch 3/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0402
# Epoch 4/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0427
# Epoch 5/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0382
# Epoch 6/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 7/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 8/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0378
# Epoch 9/10
# 55/55 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 10/10
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0378

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 484ms/step - loss: 0.1133
# 0.11325705051422119

# %%
predicted= model.predict(X_test)

# %%
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
stocks = pd.DataFrame({
    "Real Sales": real_prices.ravel(),
    "Predicted Sales": predicted_prices.ravel()
}, index = df.index[-len(real_prices): ]) 
stocks.head()
# Out:
#             Real Sales  Predicted Sales
# 2020-03-21   4757300.0       3243375.25
# 2020-03-28   4236845.0       3417921.50
# 2020-04-04   3077724.0       3617045.25
# 2020-04-11   2974870.0       3823049.50
# 2020-04-18   2788166.0       3823049.50

# %%
stocks.plot()  ## Lotion Pred vs Actual
# Out:
# <AxesSubplot:>
